# %%
# from acgan import ACGAN

# %%
# acgan = ACGAN()
# acgan.train(epochs=14000, batch_size=32, sample_interval=200)

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import os
import numpy as np
from PIL import Image
import time
from scipy import misc
from IPython import display
import matplotlib.image as mpimg
import matplotlib
from utils.image import video_from_imgs, play_video_html
from IPython.display import HTML

# %%
# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
files = os.listdir('./images/')

files.sort()

im_files = [file for file in files if '.png' in file]
 
int_files = [int(file.split('.')[0]) for file in im_files]

int_files.sort()

sorted_files = ['./images/' + str(int_file)+'.png' for int_file in int_files]

# %%
video_from_imgs(sorted_files, 'mnist.mp4', 1.5)

# %%
data = play_video_html('mnist.mp4')

# %%
HTML(data)
# Out:
# <video alt="test" controls>
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
