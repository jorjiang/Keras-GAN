# %%
from keras.models import load_model
import numpy as np

# %%
model = load_model('gen_2.5h')
# Out:
# /home/josh/anaconda3/envs/dl/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
x = model.predict(np.random.normal(0,.5,(10, 180)))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(model.predict(np.random.normal(0,.2,(1, 180)))[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
