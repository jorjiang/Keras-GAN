# %%
# %run dcgan.py
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_50 (Conv2D)           (None, 36, 36, 32)        320
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 36, 36, 32)        0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 18, 18, 64)        18496
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 19, 19, 64)        0
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 19, 19, 64)        256
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 19, 19, 64)        0
# ...
