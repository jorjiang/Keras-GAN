# %%
# %run dcgan.py
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_29 (Conv2D)           (None, 36, 36, 32)        832
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 36, 36, 32)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 18, 18, 64)        51264
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 19, 19, 64)        0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 19, 19, 64)        256
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 19, 19, 64)        0
# ...
