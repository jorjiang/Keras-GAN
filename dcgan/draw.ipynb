# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from keras.models import load_model
import numpy as np
from utils.image import video_from_imgs
import matplotlib.pyplot as plt
from utils.image import create_imgs_from_model, create_video_from_model
from utils.helper import random_walk_space

# %%
gen = load_model('./saved_model_emoji_rgb/gen_9.5h')
# Out:
# /home/josh/anaconda3/envs/dl/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning:
#
# No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
noises = random_walk_space(dim=180, step_length=0.05, length=1000, prob_change=0.05, restrict=2.5)

# %%
noises
# Out:
# array([[-1.89714584e+00,  1.27927722e+00, -3.91965707e-01, ...,
#         -9.89612970e-02, -7.71926380e-01,  8.93776143e-01],
#        [-1.84714584e+00,  1.22927722e+00, -4.41965707e-01, ...,
#         -4.89612970e-02, -7.21926380e-01,  8.43776143e-01],
#        [-1.79714584e+00,  1.17927722e+00, -4.91965707e-01, ...,
#          1.03870305e-03, -6.71926380e-01,  7.93776143e-01],
#        ...,
#        [ 3.02854163e-01, -1.87072278e+00, -9.19657068e-02, ...,
#          1.03870305e-03,  1.62807362e+00,  1.34377614e+00],
#        [ 2.52854163e-01, -1.87072278e+00, -1.41965707e-01, ...,
#          5.10387030e-02,  1.67807362e+00,  1.34377614e+00],
#        [ 2.02854163e-01, -1.87072278e+00, -1.91965707e-01, ...,
#          1.01038703e-01,  1.72807362e+00,  1.34377614e+00]])

# %%
create_video_from_model(gen, noises, 'abc.mp4', 19)

# %% [markdown]
# <video controls src="abc.mp4" />

# %%
# create_imgs_from_model(model=gen, noises=noises, img_folder='generated_emoji_rgb')

# video_from_imgs(img_folder='generated_emoji_rgb', video_file='generated_emoji.mp4', fps=19)

# %%
# import plotly.graph_objs as go
# from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# init_notebook_mode(connected=True)

# from utils.helper import random_walk_space

# x = random_walk_space(dim=3, step_length=0.05, length=100, prob_change=0.1)

# x.shape

# trace1 = go.Scatter3d(
#     x=x[:,0],
#     y=x[:,1],
#     z=x[:,2])

# layout = go.Layout(
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0
#     )
# )

# fig = go.Figure(data=[trace1], layout=layout)

# iplot(fig, show_link=False)

# position = np.random.normal(0, 1, 3)
# position

# np.random.choice([1, 0], 3)
