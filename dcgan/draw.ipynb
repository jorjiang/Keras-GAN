# %%
# %load_ext autoreload

# %autoreload 2

# %%
from keras.models import load_model
import numpy as np
from utils.image import video_from_imgs
import matplotlib.pyplot as plt
from utils.image import create_imgs_from_model, create_video_from_model
from utils.helper import random_walk_space
# Out:
# Using TensorFlow backend.

# %%
gen = load_model('./model_monet/gen_0.5h')
# Out:
# /home/josh/anaconda3/envs/dl/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
noises = random_walk_space(dim=128, step_length=0.05, length=300, prob_change=0.05, restrict=2.5)

# %%
noises
# Out:
# array([[-0.30921911, -0.41071084, -0.10040273, ...,  0.02624762,
#         -0.53171411,  0.82578675],
#        [-0.25921911, -0.41071084, -0.10040273, ...,  0.02624762,
#         -0.53171411,  0.82578675],
#        [-0.20921911, -0.41071084, -0.10040273, ...,  0.02624762,
#         -0.53171411,  0.82578675],
#        ...,
#        [-2.05921911, -1.51071084,  0.59959727, ..., -2.12375238,
#          2.01828589,  0.52578675],
#        [-2.10921911, -1.56071084,  0.64959727, ..., -2.12375238,
#          2.01828589,  0.52578675],
#        [-2.15921911, -1.61071084,  0.69959727, ..., -2.12375238,
#          2.01828589,  0.52578675]])

# %%
create_video_from_model(gen, noises, 'abc.mp4', 19)

# %%
# create_imgs_from_model(model=gen, noises=noises, img_folder='generated_emoji_rgb')

# video_from_imgs(img_folder='generated_emoji_rgb', video_file='generated_emoji.mp4', fps=19)

# %%
# import plotly.graph_objs as go
# from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# init_notebook_mode(connected=True)

# from utils.helper import random_walk_space

# x = random_walk_space(dim=3, step_length=0.05, length=100, prob_change=0.1)

# x.shape

# trace1 = go.Scatter3d(
#     x=x[:,0],
#     y=x[:,1],
#     z=x[:,2])

# layout = go.Layout(
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0
#     )
# )

# fig = go.Figure(data=[trace1], layout=layout)

# iplot(fig, show_link=False)

# position = np.random.normal(0, 1, 3)
# position

# np.random.choice([1, 0], 3)
