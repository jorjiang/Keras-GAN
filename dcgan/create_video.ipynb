# %%
from utils.image import video_from_imgs, play_video_html
import os

# %%
video = video_from_imgs('/code/dl/Keras-GAN/dcgan/image_emoji/', 'emoji_dcgan.mp4', fps=1)

# %% [markdown]
# <video controls src="emoji_dcgan.mp4" />
