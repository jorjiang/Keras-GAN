# %%
from utils.image import video_from_imgs
import os
# Out:
# Using TensorFlow backend.

# %%
video = video_from_imgs('/code/dl/Keras-GAN/dcgan/image_monet/', 'monet.mp4', fps=3)

# %% [markdown]
# <video controls src="monet.mp4" />
