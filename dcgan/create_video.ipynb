# %%
from utils.image import video_from_imgs
import os

# %%
video = video_from_imgs('/code/dl/Keras-GAN/dcgan/image_emoji_rgb//', 'flagi_dcgan.avi', fps=3)

# %% [markdown]
# <video controls src="flagi_dcgan.mp4" />
